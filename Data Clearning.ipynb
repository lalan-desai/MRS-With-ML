# %%
import pandas as pd

df = pd.read_csv('movies.csv', dtype='unicode')

df.dropna(subset=['Title', 'Genre', 'Language',  'imdbVotes', 'imdbRating', 'imdbID'], inplace=True)

df.head()
# Out:
#                           _id                                 Title  Year  \
# 5    666a8cf1fb459925bc9230dd                     Chinese Opium Den  1894
# 33   666a8cf1fb459925bc9230f9  Arrivée d'un train gare de Vincennes  1896
# 68   666a8cf1fb459925bc92311c                         Post No Bills  1896
# 173  666a8cf1fb459925bc923185       Výstavní párkar a lepic plakátù  1898
# 176  666a8cf1fb459925bc923188               The Burglar on the Roof  1898
#
#          Rated     Released Runtime               Genre              Director  \
# 5          NaN  17 Oct 1894   1 min               Short  William K.L. Dickson
# 33         NaN          NaN   1 min  Documentary, Short        Georges Méliès
# 68   Not Rated          NaN   1 min       Short, Comedy        Georges Méliès
# 173        NaN  01 Jul 1898   1 min       Short, Comedy        Jan Krízenecký
# 176  Not Rated  01 Sep 1898   1 min        Short, Crime    J. Stuart Blackton
#
#                       Writer                                   Actors  ...  \
# 5                        NaN                                      NaN  ...
# 33                       NaN                                      NaN  ...
# 68                       NaN                                      NaN  ...
# 173  Josef Sváb-Malostranský  Josef Sváb-Malostranský, Ferdinand Gýra  ...
# 176                      NaN                       J. Stuart Blackton  ...
#
#       Type  DVD BoxOffice Production Website Response totalSeasons Season  \
# 5    movie  NaN       NaN        NaN     NaN     True          NaN    NaN
# 33   movie  NaN       NaN        NaN     NaN     True          NaN    NaN
# 68   movie  NaN       NaN        NaN     NaN     True          NaN    NaN
# 173  movie  NaN       NaN        NaN     NaN     True          NaN    NaN
# 176  movie  NaN       NaN        NaN     NaN     True          NaN    NaN
#
#     Episode seriesID
# 5       NaN      NaN
# 33      NaN      NaN
# 68      NaN      NaN
# 173     NaN      NaN
# 176     NaN      NaN
#
# [5 rows x 35 columns]

# %%
filter_df = df[['Title', 'Plot', 'Genre', 'Language', 'Actors', 'imdbVotes', 'imdbRating', 'imdbID']]

# Remove commas and convert 'imdbVotes' to integer
filter_df.loc[:, 'imdbVotes'] = filter_df['imdbVotes'].str.replace(',', '').astype(int)

# Convert 'imdbRating' to float
filter_df.loc[:, 'imdbRating'] = filter_df['imdbRating'].astype(float)

# Display the DataFrame
filter_df = filter_df.dropna(subset=['Plot'])

df = filter_df[filter_df['imdbVotes'] > 10000 ]

print(df.shape)

df
# Out:
# (4319, 8)
#                                           Title  \
# 416                          A Trip to the Moon
# 438                     The Great Train Robbery
# 4964                      The Birth of a Nation
# 6855                                Intolerance
# 9953                            Broken Blossoms
# ...                                         ...
# 245926                                Baise-moi
# 246007                             Billy Elliot
# 246022                     Domestic Disturbance
# 246060                               Foodfight!
# 246217  Lady and the Tramp 2: Scamp's Adventure
#
#                                                      Plot  \
# 416     An association of astronomers has convened to ...
# 438     Among the earliest existing films in American ...
# 4964    Two brothers, Phil and Ted Stoneman, visit the...
# 6855    Intolerance and its terrible effects are exami...
# 9953    Cheng Huan is a missionary whose goal is to br...
# ...                                                   ...
# 245926  Manu and Nadine lose their last tenuous relati...
# 246007  County Durham, during the endless, violent 198...
# 246022  Susan Morrison is getting married to wealthy i...
# 246060  When the supermarket closes at night, the cont...
# 246217  Lady and Tramp's mischievous pup, Scamp, gets ...
#
#                                                  Genre         Language  \
# 416                           Short, Action, Adventure  French, English
# 438                           Short, Action, Adventure          English
# 4964                               Drama, History, War          English
# 6855                                    Drama, History          English
# 9953                                    Drama, Romance          English
# ...                                                ...              ...
# 245926                          Crime, Drama, Thriller           French
# 246007                                    Drama, Music          English
# 246022                                 Crime, Thriller          English
# 246060                    Animation, Action, Adventure          English
# 246217  Animation, Adventure, Family, Musical, Romance          English
#
#                                                    Actors imdbVotes  \
# 416         Georges Méliès, Victor André, Bleuette Bernon     55546
# 438     Gilbert M. 'Broncho Billy' Anderson, A.C. Abad...     20590
# 4964           Lillian Gish, Mae Marsh, Henry B. Walthall     26258
# 6855               Lillian Gish, Robert Harron, Mae Marsh     16594
# 9953      Lillian Gish, Richard Barthelmess, Donald Crisp     10968
# ...                                                   ...       ...
# 245926  Raffaëla Anderson, Karen Lancaume, Céline Beugnot     18526
# 246007            Jamie Bell, Julie Walters, Jean Heywood    142566
# 246022            John Travolta, Nick Loren, Matt O'Leary     28680
# 246060            Hilary Duff, Haylie Duff, Charlie Sheen     11723
# 246217  Scott Wolf, Alyssa Milano, Chazz Palminteri, J...     10962
#
#        imdbRating     imdbID
# 416           8.1  tt0000417
# 438           7.3  tt0000439
# 4964          6.2  tt0004972
# 6855          7.7  tt0006864
# 9953          7.2  tt0009968
# ...           ...        ...
# 245926        4.4  tt0249380
# 246007        7.7  tt0249462
# 246022        5.6  tt0249478
# 246060        1.3  tt0249516
# 246217        5.9  tt0249677
#
# [4319 rows x 8 columns]

# %%
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import linear_kernel

# Filter the DataFrame based on imdbVotes
df = filter_df[filter_df['imdbVotes'] > 500000]

# Set the 'imdbID' column as the index
df.set_index('imdbID', inplace=True)

# Concatenate 'Plot' and 'Genre' columns
df['Plot_Genre'] = df['Plot'] + ' ' + df['Genre'] + ' ' + df['Actors'] 

# Define a TF-IDF Vectorizer
tfidf = TfidfVectorizer(stop_words='english')

# Construct the TF-IDF matrix
tfidf_matrix = tfidf.fit_transform(df['Plot_Genre'])

# Compute the cosine similarity matrix
cosine_sim = linear_kernel(tfidf_matrix, tfidf_matrix)

def get_recommendations(imdb_id, cosine_sim=cosine_sim):
    # Get the index of the movie that matches the IMDb ID
    idx = df.index.get_loc(imdb_id)

    # Get the pairwise similarity scores of all movies with that movie
    sim_scores = list(enumerate(cosine_sim[idx]))

    # Sort the movies based on the similarity scores
    sim_scores = sorted(sim_scores, key=lambda x: x[1], reverse=True)

    # Get the scores of the 10 most similar movies
    sim_scores = sim_scores[1:11]

    # Get the movie indices
    movie_indices = [i[0] for i in sim_scores]

    # Return the top 10 most similar movies
    return df.iloc[movie_indices]

# Example: Get recommendations for a movie by IMDb ID
movie_imdb_id = "tt0071562"  # IMDb ID for "The Godfather"
recommendations = get_recommendations(movie_imdb_id)
print("Recommendations for the movie with IMDb ID", movie_imdb_id, ":")
recommendations
# Out:
# Recommendations for the movie with IMDb ID tt0071562 :
# C:\Users\lalan\AppData\Local\Temp\ipykernel_19500\3205926069.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Plot_Genre'] = df['Plot'] + ' ' + df['Genre'] + ' ' + df['Actors']
#                         Title  \
# imdbID
# tt0068646       The Godfather
# tt0112641              Casino
# tt0075314         Taxi Driver
# tt0209144             Memento
# tt0099685          Goodfellas
# tt0113277                Heat
# tt0086250            Scarface
# tt0099785          Home Alone
# tt0097165  Dead Poets Society
# tt0108778             Friends
#
#                                                         Plot  \
# imdbID
# tt0068646  The Godfather "Don" Vito Corleone is the head ...
# tt0112641  This Martin Scorsese film depicts the Janus-li...
# tt0075314  Travis Bickle is an ex-Marine and Vietnam War ...
# tt0209144  Memento chronicles two separate stories of Leo...
# tt0099685  Henry Hill might be a small time gangster, who...
# tt0113277  Hunters and their prey--Neil and his professio...
# tt0086250  Tony Montana manages to leave Cuba during the ...
# tt0099785  It is Christmas time and the McCallister famil...
# tt0097165  Painfully shy Todd Anderson has been sent to t...
# tt0108778  Ross Geller, Rachel Green, Monica Geller, Joey...
#
#                              Genre  \
# tt0054215     Horror, Mystery, Thriller     721707         8.5
# ...                                 ...        ...         ...
# tt0240772               Crime, Thriller     618831         7.7
# tt0241527    Adventure, Family, Fantasy     860139         7.6
# tt0242653                Action, Sci-Fi     545548         6.7
# tt0245429  Animation, Adventure, Family     854969         8.6
# tt0246578        Drama, Mystery, Sci-Fi     853663         8.0
#
# [104 rows x 5 columns]

# %%
preferred_languages = ['Spanish']
preferred_genres = ['Crime', 'Drama',]


# Function to recommend top 10 movies for each genre and preferred languages
def recommend_movies_by_genre_and_language(genre, languages):
    # Filter dataframe for the given genre and preferred languages
    genre_df = df[df['Genre'].str.contains(genre) & df['Language'].apply(lambda x: any(lang in x for lang in languages))]

    # Sort by imdbVotes and imdbRating in descending order
    sorted_df = genre_df.sort_values(by=['imdbVotes', 'imdbRating'], ascending=False)

    # Select top 10 movies
    top_movies = sorted_df.head(10)
    
    return top_movies

# Generate recommendations for each genre and preferred languages
recommendations = {}
for genre in preferred_genres:
    recommendations[genre] = recommend_movies_by_genre_and_language(genre, preferred_languages)

# Print recommendations
for genre, movies in recommendations.items():
    print(f"\nTop 10 Movies in {genre} for Preferred Languages:\n")
    print(movies)
# Out:
# Top 10 Movies in Crime for Preferred Languages:
#
#                            Title                                    Language  \
# imdbID
# tt0110912           Pulp Fiction                    English, Spanish, French
# tt0071562  The Godfather Part II  English, Italian, Spanish, Latin, Sicilian
# tt0114814     The Usual Suspects         English, Hungarian, Spanish, French
# tt0075314            Taxi Driver                            English, Spanish
# tt0086250               Scarface                            English, Spanish
# tt0118715       The Big Lebowski            English, German, Hebrew, Spanish
# tt0144084        American Psycho                 English, Spanish, Cantonese
# tt0113277                   Heat                            English, Spanish
#
#                            Genre  imdbVotes  imdbRating
# imdbID
# tt0110912           Crime, Drama    2232974         8.9
# tt0071562           Crime, Drama    1361708         9.0
# tt0114814  Crime, Drama, Mystery    1149941         8.5
# tt0075314           Crime, Drama     926206         8.2
# tt0086250           Crime, Drama     915945         8.3
# tt0118715          Comedy, Crime     862821         8.1
# tt0144084   Crime, Drama, Horror     719912         7.6
# tt0113277   Action, Crime, Drama     715349         8.3
#
# Top 10 Movies in Drama for Preferred Languages:
#
#                            Title  \
# imdbID
# tt0110912           Pulp Fiction
# tt0071562  The Godfather Part II
# tt0114814     The Usual Suspects
# tt0167404        The Sixth Sense
# tt0075314            Taxi Driver
# tt0086250               Scarface
# tt0144084        American Psycho
# tt0113277                   Heat
# tt0206634        Children of Men
#
#                                                     Language  \
# imdbID
# tt0110912                           English, Spanish, French
# tt0071562         English, Italian, Spanish, Latin, Sicilian
# tt0114814                English, Hungarian, Spanish, French
# tt0167404                            English, Latin, Spanish
# tt0075314                                   English, Spanish
# tt0086250                                   English, Spanish
# tt0144084                        English, Spanish, Cantonese
# tt0113277                                   English, Spanish
# tt0206634  English, German, Italian, Romanian, Spanish, A...
#
#                               Genre  imdbVotes  imdbRating
# imdbID
# tt0110912              Crime, Drama    2232974         8.9
# tt0071562              Crime, Drama    1361708         9.0
# tt0114814     Crime, Drama, Mystery    1149941         8.5
# tt0167404  Drama, Mystery, Thriller    1047165         8.2
# tt0075314              Crime, Drama     926206         8.2
# tt0086250              Crime, Drama     915945         8.3
# tt0144084      Crime, Drama, Horror     719912         7.6
# tt0113277      Action, Crime, Drama     715349         8.3
# tt0206634     Action, Drama, Sci-Fi     530987         7.9
