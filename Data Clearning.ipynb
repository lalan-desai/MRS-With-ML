# %%
import pandas as pd

df = pd.read_csv('movies_dataset.csv')

df.head()
# Out:
#                     Title  Year      Rated     Released Runtime  \
# 0              Carmencita  1894  Not Rated  10 Mar 1894   1 min
# 1  Le clown et ses chiens  1892        NaN  16 Nov 1892   5 min
# 2          Pauvre Pierrot  1892      TV-PG  28 Oct 1892   4 min
# 3             Un bon bock  1892        NaN  28 Oct 1892  12 min
# 4        Blacksmith Scene  1893    Unrated  09 May 1893   1 min
#
#                       Genre              Director Writer  \
# 0        Documentary, Short  William K.L. Dickson    NaN
# 1          Animation, Short         Émile Reynaud    NaN
# 2  Animation, Comedy, Short         Émile Reynaud    NaN
# 3          Animation, Short         Émile Reynaud    NaN
# 4             Short, Comedy  William K.L. Dickson    NaN
#
#                      Actors  \
# 0                Carmencita
# 1                       NaN
# 2                       NaN
# 3                       NaN
# 4  Charles Kayser, John Ott
#
# ...

# %%
df.columns
# Out:
# Index(['Title', 'Year', 'Rated', 'Released', 'Runtime', 'Genre', 'Director',
#        'Writer', 'Actors', 'Plot', 'Language', 'Country', 'Awards', 'Poster',
#        'Metascore', 'imdbRating', 'imdbVotes', 'imdbID', 'Type', 'DVD',
#        'BoxOffice', 'Production', 'Website', 'Response'],
#       dtype='object')

# %%
df.shape
# Out:
# (1891, 24)

# %%
new_df = df[['Title', 'Genre', 'Director', 'Writer', 'Actors', 'Plot', 'imdbRating', 'imdbVotes', 'imdbID', ]]

new_df
# Out:
#                             Title                     Genre  \
# 0                      Carmencita        Documentary, Short
# 1          Le clown et ses chiens          Animation, Short
# 2                  Pauvre Pierrot  Animation, Comedy, Short
# 3                     Un bon bock          Animation, Short
# 4                Blacksmith Scene             Short, Comedy
# ...                           ...                       ...
# 1886            The Spanish Gypsy            Romance, Short
# 1887   Spike Shannon's Last Fight            Short, Western
# 1888                 Sport Hípico               Documentary
# 1889             The Squaw's Love     Drama, Short, Western
# 1890  The Stage Driver's Daughter            Short, Western
#
#                                  Director  \
# 0                    William K.L. Dickson
# 1                           Émile Reynaud
# 2                           Émile Reynaud
# 3                           Émile Reynaud
# ...

# %%
new_df.columns
# Out:
# Index(['Title', 'Genre', 'Director', 'Writer', 'Actors', 'Plot', 'imdbRating',
#        'imdbVotes', 'imdbID'],
#       dtype='object')

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import linear_kernel
from sklearn.preprocessing import MultiLabelBinarizer
import pandas as pd



# Feature Engineering
# Convert genre, director, writer, and actors into a bag-of-words representation
features = ['Genre', 'Director', 'Writer', 'Actors', 'Plot']
df['combined_features'] = df[features].apply(lambda row: ' '.join(row.values.astype(str)), axis=1)

# TF-IDF Vectorization
tfidf_vectorizer = TfidfVectorizer(stop_words='english')
tfidf_matrix = tfidf_vectorizer.fit_transform(df['combined_features'])

# Similarity Calculation
cosine_sim = linear_kernel(tfidf_matrix, tfidf_matrix)

# Recommendation Generation
def recommend_movies(movie_title, cosine_sim=cosine_sim, df=df):
    try:
        idx = df[df['Title'] == movie_title].index[0]
    except IndexError:
        print(f"Movie '{movie_title}' not found in the dataset.")
        return pd.DataFrame()  # Return an empty DataFrame if movie not found
    sim_scores = list(enumerate(cosine_sim[idx]))
    sim_scores = sorted(sim_scores, key=lambda x: x[1], reverse=True)
    sim_scores = sim_scores[1:11]  # Top 10 similar movies
    movie_indices = [i[0] for i in sim_scores]
    recommended_movies = new_df.iloc[movie_indices].drop(columns=['Plot',  'imdbVotes', 'imdbID'])  # Drop the 'Plot' column
    return recommended_movies
    
# Example usage
recommendations = recommend_movies('The Sorrowful Example')
recommendations
# Out:
#                       Title                  Genre            Director  \
# 1440   A Victim of Jealousy           Drama, Short       D.W. Griffith
# 1469         After the Ball          Comedy, Short        Frank Powell
# 637      At the French Ball          Short, Comedy  Wallace McCutcheon
# 1012        The Restoration           Short, Drama       D.W. Griffith
# 1456  Winning Back His Love  Drama, Short, Romance       D.W. Griffith
# 1678    His Trust Fulfilled           Short, Drama       D.W. Griffith
# 1382         The Rocky Road           Short, Drama       D.W. Griffith
# 1257         The Impalement           Short, Drama       D.W. Griffith
# 1813    Out from the Shadow           Short, Drama       D.W. Griffith
# 1076    Two Women and a Man           Short, Drama       D.W. Griffith
#
#                    Writer                                             Actors  \
# 1440  Stanner E.V. Taylor     James Kirkwood, Florence Barker, Mary Pickford
# ...

# %%
new_df[new_df['Title'] == 'The Sorrowful Example'].drop(columns=['Plot',  'imdbVotes', 'imdbID'])
# Out:
#                       Title         Genre       Director Writer  \
# 1884  The Sorrowful Example  Drama, Short  D.W. Griffith    NaN
#
#                                                  Actors  imdbRating
# 1884  Wilfred Lucas, Claire McDowell, Florence La Ba...         NaN

# %%
new_df
# Out:
#                             Title                     Genre  \
# 0                      Carmencita        Documentary, Short
# 1          Le clown et ses chiens          Animation, Short
# 2                  Pauvre Pierrot  Animation, Comedy, Short
# 3                     Un bon bock          Animation, Short
# 4                Blacksmith Scene             Short, Comedy
# ...                           ...                       ...
# 1886            The Spanish Gypsy            Romance, Short
# 1887   Spike Shannon's Last Fight            Short, Western
# 1888                 Sport Hípico               Documentary
# 1889             The Squaw's Love     Drama, Short, Western
# 1890  The Stage Driver's Daughter            Short, Western
#
#                                  Director  \
# 0                    William K.L. Dickson
# 1                           Émile Reynaud
# 2                           Émile Reynaud
# 3                           Émile Reynaud
# ...
